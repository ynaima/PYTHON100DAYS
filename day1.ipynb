# %% [markdown]
# 1) String manipulation
# Syntax errors
# identation errors
# Use of newline character to break sentences to different lines
# Comments are used to add notes/descriptions into your code and it is does not get executed. it is marked with # as used in code line 3

# %%
#newline character \n
print("When the sun shines \nSun rays hitting the yellow waters of Akisa water \nWaves and cheerful whispers from the crowd \nAn indication of the current atmosphere of Akisa Village")
# Out:
# When the sun shines
# Sun rays hitting the yellow waters of Akisa water
# Waves and cheerful whispers from the crowd
# An indication of the current atmosphere of Akisa Village

# %% [markdown]
# 2) String concatenation using the plus character

# %% [markdown]
# 3) The input function in python - prompting user for input (we get string characters)
# example below

# %%
input("What is your name?")
# Out:
# What is your name? Naimo
# 'Naimo'

# %% [markdown]
# We can use the users input, use it and print it to the screen as follows using string concatenation

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Naima
# Hello Naima!

# %%
4) Variables - now we can store the users input in variable names to use it later in our code

# %%
#using the variable answer to store the answer to the question from the user
Answer = input("What is a mammal that can fly")

#now using the users answer stored in Answer and printing it to the screen
print("The answer is a " + Answer)
# Out:
# What is a mammal that can fly Bat
# The answer is a Bat

# %%
#challenge1
#find the number of characters in the users input
word = input ("Give me a word: ")
print("Your word is " + word +  " and it is " + str(len(word)) + " characters long")
# Out:
# Give me a word:  Photosynthesis
# Your word is Photosynthesis and it is 14 characters long

# %%
#challenge2
glass1 = "milk"
glass2 = "juice"
#swap the contents of the following variables such that glass 1 now contains juice and glass2 contains milk
#temp variables stores the content of glass1 temporarily
temp = glass1
glass1 = glass2
glass2 = temp
print("glass1= " + glass1)
print("glass2= " + glass2)
# Out:
# glass1= juice
# glass2= milk

# %% [markdown]
# Variable Naming
# -cannot start with numbers or symbols
# - can start with character or underline symbol
# - do not use python built-in functions
# - Name error - (usually as a result of misspelt variable name or using undefined variable name)
